# %% [markdown]
# ###### Jonathan Harper
# ###### Programming for Data Analytics
# ***

# %% [markdown]
# # Wine data introduction

# %% [markdown]
# It was (Sir) Cliff Richard himself*, who first suggested that the conundrum contained in the riddle locked inside the enigma that is wine could perhaps be solved by using the unparralelled computational power of NumPy with his Christmas chart topping hit "NumPy and wine". This notebook aims to build on that prophetic marrage of vision, lyrical genious and harmony (The song was released in 1988 a full 7 years before the first NumPy predecessor package (Numeric) emerged in '95).
#
# A number** of Academics have speculated that Sir Cliffs dissapearance from popular culture, from the 1990 number one Saviour's day to 1999's Milenium prayer was infact time spent heading up a team at MIT to develop the first structures that underpin the present NumPy package. It should be noted that Python masters such as Guido Van Rossum, Jim Hugunin and Travis Oliphant has never spoken on record to deny this claim not has MIT come forward to counter this.
#
# Below is an image of Sir Cliff handing over a Christmas gift. We can assume it was the perfect wine.
#
# ![image.png](attachment:image.png)
#
# ###### "Christmas time, Num-hum-Py and Wine" Cliff Richard
# ###### * completely untrue,  ** 0

# %% [markdown]
# ###### The construction of this package will concentrate on 4 varyables assotiated with Wine
# 1. Overall rating
# 2. Price
# 3. Age of the wine at consumption
# 4. Country of origin of the wine
#
# Following the investigation of each varable the information accessed will be used to define the input to a dataframe that will be generated using the NumPy Random Package.
